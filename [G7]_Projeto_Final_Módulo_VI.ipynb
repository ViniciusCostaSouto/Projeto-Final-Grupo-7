# %% [markdown]
# <a href="https://colab.research.google.com/github/ViniciusCostaSouto/Projeto-Final-Grupo-7/blob/main/%5BG7%5D_Projeto_Final_M%C3%B3dulo_VI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # <font color='white' style='font-size: 30px;'>Projeto de encerramento do módulo 6: Análise de Gastos dos Deputados Federais do *Rio Grande do Sul* nos anos de 2019, 2020 e 2021 </font>
# <hr style='border: 2px solid red;'>

# %% [markdown]
# ## **1. O Grupo**
#
#  O Grupo 9 é formado pelos integrantes citados abaixo, com seus respectivos endereços de GitHub e LinkedIn.
#
# *  Bruna Pereira
#   - [GitHub](https://github.com/BrunaFPereira)
#   - [LinkedIn](https://www.linkedin.com/in/brunafp1590/)
#
# *  Dayana Prado
#   - [GitHub](https://github.com/Ayaminue)
#   - [LinkedIn](https://www.linkedin.com/in/dayana-prado-/)
#
# *  Henrique Lima
#   - [GitHub](https://github.com/Henrikenzie)
#   - [LinkedIn](https://www.linkedin.com/in/henrique-l-584358108/)
#
# *  Jônathas Hessel
#   - [GitHub](https://github.com/JonatasHesselTaveira)
#   - [LinkedIn](https://www.linkedin.com/in/jonatashessel/)
#
# *  Vinícius Costa Souto
#   - [GitHub](https://github.com/ViniciusCostaSouto)
#   - [LinkedIn](https://www.linkedin.com/in/vin%C3%ADcius-costa-souto-937966164/)
#
# ---

# %% [markdown]
# ## **2. Descrição do Projeto (Pdf)**
#
# Você e sua equipe foram escalados novamente pela Procuradoria Geral da
# República para dar continuidade a investigação dos gastos dos parlamentares brasileiros nos anos de 2019, 2020 e 2021. As análises feitas anteriormente chamaram a atenção da Polícia Federal (PF) para operações que irão ocorrer simultaneamente em todos os estados. Por isso, o Procurador Geral da República está solicitando que você e sua equipe apresentem ao seleto grupo de delegados da PF os fatos encontrados nos gastos dos parlamentares que mais chamaram a atenção de vocês. Para isso vocês podem utilizar os resultados encontrados no módulo anterior ou realizar mais análises sob os dados. Ressaltamos que a Cota para o Exercício da Atividade Parlamentar é regida por uma série de regras que podem ser consultadas [aqui](https://www2.camara.leg.br/legin/int/atomes/2009/atodamesa-43-21-maio-2009-588364-norma-cd-mesa.html) e que há algumas iniciativas, como o [Serenata de Amor](https://serenata.ai/), que visam acompanhar os gastos realizados pelos nossos políticos e podem ser utilizadas para auxiliar na geração de insights. Como são muitos parlamentares, a análise das despesas devem ser realizadas por região. Por tanto, cada equipe será responsável por apresentar suas análises das despesas dos parlamentares de um estado:
#
#  - Equipe 01: MT;
#  - Equipe 02: MG;
#  - Equipe 03: SP;
#  - Equipe 04: BA;
#  - Equipe 05: PA;
#  - Equipe 06: MS;
#  - ***Equipe 07: RS***; (Nossa equipe)
#  - Equipe 08: CE;
#  - Equipe 09: TO;
#  - Equipe 10: PR;
#
# A apresentação do projeto deverá obrigatoriamente:
# * Conter gráficos adequados para o tipo de dado e informação;
# * Utilizar visualizações construídas no Tableau ou Power Bi (o grupo pode
# escolher qual ferramenta irá utilizar);
# * Utilizar conceitos de Storytelling;
# * Apresentar em slides (e.g., Power Point, História (Tableau));
# * Ser apresentada por todos os integrantes do grupo;
# * Ter duração máxima de 10 minutos.
#
# **As perguntas a serem respondidas são:**
#
# 1. Como se comportam os gastos com cotas parlamentares ao longo
# do tempo? Existe alguma tendência de aumento ou redução desse
# custo?
#
# 2. Qual a média de gastos por parlamentar?
#
# 3. Quais foram os parlamentares que mais e que menos consumiram
# recursos?
#
# 4. Quais são as categorias de despesas mais onerosas dentre os
# recursos destinados às cotas parlamentares?

# %% [markdown]
# ## **3. O Projeto deverá obrigatoriamente:**
#
# * Utilizar Jupyter Notebook ou Colab;
# * Realizar a limpeza dos dados;
# * Realizar análise exploratório;
# * Responder cada uma das perguntas com a visualização mais adequada;
# * O notebook utilizado na análise deve estar organizado, com descrições
# do passo a passo da análise em markdown, apresentação dos resultados e
# insights gerados;
# * Levantar mais duas perguntas e respondê-las com a visualização mais
# adequada.
#
# Apresentação:
# * Todos os integrantes do grupo deverão apresentar
# * Apresente a análise realizada e organizada no Jupyter Notebook ou
# Colab
# * Utilize slides de apoio para sua apresentação
# * Seu grupo terá 15 minutos (no máximo) para apresentar
#
#
#
# ---

# %% [markdown]
# ## **4. Entendendo os Dados:**
#
# Este projeto visa a análise dos dados referentes às despesas públicas pessoais de parlamentares do Rio Grande do Sul. A Cota para o Exercício da Atividade Parlamentar – CEAP – é uma verba indenizatória à qual os deputados federais e os senadores têm direito para custear as despesas do mandato, com passagens aéreas, alimentação, divulgação da atividade parlamentar, entre outras.
# O valor da cota varia entre os estados devido às diferentes distâncias de Brasília para cada localidade do Brasil. Nesta etapa estaremos coletando os dados iniciais, descrevendo os referidos dados, bem como explorando os dados com as estatísticas descritivas e por fim, verificando a qualidade de dados.

# %% [markdown]
# ### **4.1 Importando as bibliotecas:**

# %% [markdown]
# **Eixo base:**
#  1. NumPy
#
# Biblioteca de manipulação de arrays multidimensionais de alta performance, possui diversas funções matemáticas e estatísticas.
#
#  2. Pandas
#
# Principal biblioteca de manipulação e análise de dados. Possui diversos métodos para agrupar, filtrar, manipular, limpar e combinar dados de forma simples.
#
# **Data Visualization:**
#
#  3. Matplotlib
#
# O matplotlib é uma biblioteca com recursos para a geração de gráficos 2D a partir de arrays.
#
#  4. Seaborn
#
# O Seaborn é uma biblioteca de visualização de dados do Python baseado no Matplotlib. Ele provê uma interface de alto nível para construção de gráficos estatísticos atrativos e informativos.

# %%
# Carregando os pacotes do Python necessários 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
import calendar

# %% [markdown]
# ### **4.2 Coletando os dados iniciais:**

# %% [markdown]
# Subindo os dataframes divididos por seus anos respectivos

# %%
data_2019 = pd.read_csv("https://raw.githubusercontent.com/ViniciusCostaSouto/Projeto-Modulo-5-Grupo-9/main/Ano-2019.csv", sep= ';', dtype={'cpf': 'str'}, encoding = 'utf-8')
data_2019.head()
# Out:
#   txNomeParlamentar  cpf  ideCadastro  nuCarteiraParlamentar  nuLegislatura  \
# 0        LID.GOV-CD  NaN          NaN                    NaN           2015
# 1        LID.GOV-CD  NaN          NaN                    NaN           2019
# 2        LID.GOV-CD  NaN          NaN                    NaN           2019
# 3        LID.GOV-CD  NaN          NaN                    NaN           2019
# 4        LID.GOV-CD  NaN          NaN                    NaN           2019
#
#   sgUF sgPartido  codLegislatura  numSubCota  \
# 0  NaN       NaN              55          13
# 1  NaN       NaN              56          13
# 2  NaN       NaN              56          13
# 3  NaN       NaN              56          13
# 4  NaN       NaN              56          13
#
#                                  txtDescricao  ...  numAno numParcela  \
# 0  FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR  ...    2019          0
# 1  FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR  ...    2019          0
# ...

# %%
data_2020 = pd.read_csv("https://raw.githubusercontent.com/ViniciusCostaSouto/Projeto-Modulo-5-Grupo-9/main/Ano-2020.csv", sep= ';', dtype={'cpf': 'str'}, encoding = 'utf-8')
data_2020.head()
# Out:
#          txNomeParlamentar  cpf  ideCadastro  nuCarteiraParlamentar  \
# 0  LIDERANÇA DO DEMOCRATAS  NaN          NaN                    NaN
# 1  LIDERANÇA DO DEMOCRATAS  NaN          NaN                    NaN
# 2  LIDERANÇA DO DEMOCRATAS  NaN          NaN                    NaN
# 3  LIDERANÇA DO DEMOCRATAS  NaN          NaN                    NaN
# 4  LIDERANÇA DO DEMOCRATAS  NaN          NaN                    NaN
#
#    nuLegislatura sgUF sgPartido  codLegislatura  numSubCota  \
# 0           2019  NaN       NaN              56           4
# 1           2019  NaN       NaN              56           4
# 2           2019  NaN       NaN              56           4
# 3           2019  NaN       NaN              56           4
# 4           2019  NaN       NaN              56           5
#
#                                     txtDescricao  ...  numAno numParcela  \
# 0  CONSULTORIAS, PESQUISAS E TRABALHOS TÉCNICOS.  ...    2020          0
# ...

# %%
data_2021 = pd.read_csv("https://raw.githubusercontent.com/ViniciusCostaSouto/Projeto-Modulo-5-Grupo-9/main/Ano-2021.csv", sep= ';', dtype={'cpf': 'str'}, encoding = 'utf-8')
data_2021.head()
# Out:
#         txNomeParlamentar  cpf  ideCadastro  nuCarteiraParlamentar  \
# 0  LIDERANÇA DO CIDADANIA  NaN          NaN                    NaN
# 1  LIDERANÇA DO CIDADANIA  NaN          NaN                    NaN
# 2  LIDERANÇA DO CIDADANIA  NaN          NaN                    NaN
# 3  LIDERANÇA DO CIDADANIA  NaN          NaN                    NaN
# 4  LIDERANÇA DO CIDADANIA  NaN          NaN                    NaN
#
#    nuLegislatura sgUF sgPartido  codLegislatura  numSubCota  \
# 0           2019  NaN       NaN              56          13
# 1           2019  NaN       NaN              56          13
# 2           2019  NaN       NaN              56          13
# 3           2019  NaN       NaN              56          13
# 4           2019  NaN       NaN              56          13
#
#                                  txtDescricao  ...  numAno numParcela  \
# 0  FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR  ...    2021          0
# ...

# %%
df = pd.read_csv("https://raw.githubusercontent.com/ViniciusCostaSouto/Projeto-Modulo-5-Grupo-9/main/Ano-2021.csv", sep= ';', dtype={'cpf': 'str'}, encoding = 'utf-8')
data_2021.head()

# %% [markdown]
# ### **4.3 Unindo os dados:**

# %%
dfInicialBR = pd.concat([data_2019, data_2020, data_2021], ignore_index=True)
dfInicialBR.head()
# Out:
#   txNomeParlamentar  cpf  ideCadastro  nuCarteiraParlamentar  nuLegislatura  \
# 0        LID.GOV-CD  NaN          NaN                    NaN           2015
# 1        LID.GOV-CD  NaN          NaN                    NaN           2019
# 2        LID.GOV-CD  NaN          NaN                    NaN           2019
# 3        LID.GOV-CD  NaN          NaN                    NaN           2019
# 4        LID.GOV-CD  NaN          NaN                    NaN           2019
#
#   sgUF sgPartido  codLegislatura  numSubCota  \
# 0  NaN       NaN              55          13
# 1  NaN       NaN              56          13
# 2  NaN       NaN              56          13
# 3  NaN       NaN              56          13
# 4  NaN       NaN              56          13
#
#                                  txtDescricao  ...  numAno numParcela  \
# 0  FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR  ...    2019          0
# 1  FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR  ...    2019          0
# ...

# %% [markdown]
# ### **4.4 Descrevendo os dados:**

# %% [markdown]
# #### 4.4.1 **Dicionário das Variáveis**

# %% [markdown]
# **1.** **`txNomeParlamentar`** (*Nome Parlamentar*): Nome adotado pelo Parlamentar ao tomar posse do seu mandato. Compõe-se de dois elementos: um prenome e o nome; dois nomes; ou dois prenomes, salvo, a juízo do Presidente da Casa legislativa, que poderá alterar essa regra para que não ocorram confusões.
#
# **2.** **`ideCadastro`** (*Identificador Único do Parlamentar*): Número que identifica unicamente um deputado federal na CD.
#
# **3.** **`nuCarteiraParlamentar`** (*Número da  Carteira Parlamentar*): Documento usado para identificar um deputado federal na CD. Pode alterar a cada Legislatura nova.
#
# **4.** **`nuLegislatura`** (*Número da  Legislatura*): Legislatura: Período de quatro anos coincidente com o mandato parlamentar dos Deputados Federais. No contexto da cota CEAP, representa o ano base de início da legislatura e é utilizado para compor a Carteira Parlamentar, pois esta poderá ser alterada à medida que se muda de Legislatura.
#
# **5.** **`sgUF`** (*Sigla da UF*): No contexto da cota CEAP, representa a unidade da federação pela qual o deputado foi eleito e é utilizada para definir o valor da cota a que o deputado tem.
#
# **6.** **`sgPartido`** (*Sigla do Partido*): O seu conteúdo representa a sigla de um partido. Definição de partido: é uma organização formada por pessoas com interesse ou ideologia comuns, que se associam com o fim de assumir o poder para implantar um programa de governo. Tem personalidade jurídica de direito privado e goza de autonomia e liberdade no que diz respeito à criação, organização e funcionamento, observados os princípios e preceitos constitucionais.
#
# **7.** **`codLegislatura`** (*Código da Legislatura*): Legislatura: Período de quatro anos coincidente com o mandato parlamentar dos Deputados Federais. No contexto da cota CEAP, o seu conteúdo representa o código identificador da Legislatura, que um número ordinal sequencial, alterado de um em um, a cada início de uma nova Legislatura (por exemplo, a Legislatura que iniciou em 2011 é a 54ª Legislatura).
#
# **8.** **`numSubCota`** (*Número da Subcota*): No contexto da Cota CEAP, o conteúdo deste dado representa o código do Tipo de Despesa referente à despesa realizada pelo deputado e comprovada por meio da emissão de um documento fiscal, a qual é debitada na cota do deputado.
#
# **9.** **`txtDescricao`** (*Descrição da Subcota*): O seu conteúdo é a descrição do Tipo de Despesa relativo à despesa em questão.
#
# **10.** **`numEspecificacaoSubCota`** (*Número da Especificação da Subcota*): No contexto da Cota CEAP, há despesas cujo Tipo de Despesa necessita ter uma especificação mais detalhada (por exemplo, “Combustível”). O conteúdo deste dado representa o código desta especificação mais detalhada.
#
# **11.** **`txtDescricaoEspecificacao`** (*Descrição da Especificação da Subcota*): Representa a descrição  especificação mais detalhada de um referido Tipo de Despesa.
#
# **12.** **`txtFornecedor`** (*Fornecedor*): O conteúdo deste dado representa o nome do fornecedor do produto ou serviço presente no documento fiscal
#
# **13.** **`txtCNPJCPF`** (*CNPJ/CPF*): O conteúdo deste dado representa o CNPJ ou o CPF do emitente do documento fiscal, quando se tratar do uso da cota em razão do reembolso despesas comprovadas pela emissão de documentos fiscais.
#
# **14.** **`txtNumero`** (*Número do Documento*): O conteúdo deste dado representa o número de face do documento fiscal emitido ou o número do documento que deu causa à despesa debitada na cota do deputado.
#
# **15.** **`indTipoDocumento`** (*Indicativo de Tipo de Documento Fiscal*): Este dado representa o tipo de documento do fiscal – 0 (Zero), para Nota Fiscal; 1 (um), para Recibo; e 2, para Despesa no Exterior.
#
# **16.** **`datEmissao`** (*Data de Emissão*): O conteúdo deste dado é a data de emissão do documento fiscal ou a data do documento que tenha dado causa à despesa.
#
# **17.** **`vlrDocumento`** (*Valor do Documento*): O seu conteúdo é o valor de face do documento fiscal ou o valor do documento que deu causa à despesa. Quando se tratar de bilhete aéreo, esse valor poderá ser negativo, significando que o referido bilhete é um bilhete de compensação, pois compensa um outro bilhete emitido e não utilizado pelo deputado (idem para o dado vlrLiquido abaixo).
#
# **18.** **`vlrGlosa`** (*Valor da Glosa*): O seu conteúdo representa o valor da glosa do documento fiscal que incidirá sobre o Valor do Documento, ou o valor da glosa do documento que deu causa à despesa.
#
# **19.** **`vlrLiquido`** (*Valor Líquido*): O seu conteúdo representa o valor líquido do documento fiscal ou do documento que deu causa à despesa e será calculado pela diferença entre o Valor do Documento e o Valor da Glosa. É este valor que será debitado da cota do deputado. Caso o débito seja do Tipo Telefonia e o valor seja igual a zero, significa que a despesa foi franqueada.
#
# **20.** **`numMes`** (*Mês*): O seu conteúdo representa o Mês da competência financeira do documento fiscal ou do documento que deu causa à despesa. É utilizado, junto com o ano, para determinar em que período o débito gerará efeito financeiro sobre a cota.
#
# **21.** **`numAno`** (*Ano*): O seu conteúdo representa o Ano da competência financeira do documento fiscal ou do documento que deu causa à despesa. É utilizado, junto com o mês, para determinar em que período o débito gerará efeito financeiro sobre a cota.
#
# **22.** **`numParcela`** (*Número da Parcela*): O seu conteúdo representa o número da parcela do documento fiscal. Ocorre quando o documento tem de ser reembolsado de forma parcelada.
#
# **23.** **`txtPassageiro`** (*Passageiro*): O conteúdo deste dado representa o nome do passageiro, quando o documento que deu causa à despesa se tratar de emissão de bilhete aéreo.
#
# **24.** **`txtTrecho`** (*Trecho*): O conteúdo deste dado representa o trecho da viagem, quando o documento que deu causa à despesa se tratar de emissão de bilhete aéreo.
#
# **25.** **`numLote`** (*Número do Lote*): No contexto da Cota CEAP, o Número do Lote representa uma capa de lote que agrupa os documentos que serão entregues à Câmara para serem ressarcidos. Este dado, juntamente com o Número do Ressarcimento, auxilia a localização do documento no Arquivo da Casa.
#
# **26.** **`numRessarcimento`** (*Número do Ressarcimento*): No contexto da Cota CEAP, o Número do Ressarcimento indica o ressarcimento do qual o documento fez parte por ocasião do processamento do seu reembolso. Este dado, juntamente com o Número do Ressarcimento, auxilia a localização do documento no Arquivo da Casa.
#
# **27.** **`vlrRestituicao`** (*Valor da Restituição*): O seu conteúdo representa o valor restituído do documento fiscal que incidirá sobre o Valor do Documento.
#
# **28.** **`nuDeputadoId`** (*Identificador do Solicitante*): Número que identifica um Parlamentar ou Liderança na Transparência da Cota para Exercício da Atividade Parlamentar.
#
# **29.** **`cpf`** (*CPF*): CPF do parlamentar.
#
# **30.** **`ideDocumento`** (*id do Documento*): Não há informação referente ao que se trata essa coluna.
#
# **31.** **`urlDocumento`** (*url do Documento*): Url da nota fiscal do gasto.

# %%
# Conhecendo o formato do dataset.

df.shape
# Out:
# (555500, 31)

# %%
# Conhecendo as varíaveis e seus tipos.

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 555500 entries, 0 to 555499
# Data columns (total 31 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   txNomeParlamentar          555500 non-null  object
#  1   cpf                        553661 non-null  object
#  2   ideCadastro                553759 non-null  float64
#  3   nuCarteiraParlamentar      553759 non-null  float64
#  4   nuLegislatura              555500 non-null  int64
#  5   sgUF                       553759 non-null  object
#  6   sgPartido                  553759 non-null  object
#  7   codLegislatura             555500 non-null  int64
#  8   numSubCota                 555500 non-null  int64
#  9   txtDescricao               555500 non-null  object
#  10  numEspecificacaoSubCota    555500 non-null  int64
#  11  txtDescricaoEspecificacao  136177 non-null  object
#  12  txtFornecedor              555467 non-null  object
# ...

# %%
# Visualizar as 5 primeiras linhas do Dataset.

df.head()
# Out:
#   txNomeParlamentar  cpf  ideCadastro  nuCarteiraParlamentar  nuLegislatura  \
# 0        LID.GOV-CD  NaN          NaN                    NaN           2015
# 1        LID.GOV-CD  NaN          NaN                    NaN           2019
# 2        LID.GOV-CD  NaN          NaN                    NaN           2019
# 3        LID.GOV-CD  NaN          NaN                    NaN           2019
# 4        LID.GOV-CD  NaN          NaN                    NaN           2019
#
#   sgUF sgPartido  codLegislatura  numSubCota  \
# 0  NaN       NaN              55          13
# 1  NaN       NaN              56          13
# 2  NaN       NaN              56          13
# 3  NaN       NaN              56          13
# 4  NaN       NaN              56          13
#
#                                  txtDescricao  ...  numAno numParcela  \
# 0  FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR  ...    2019          0
# 1  FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR  ...    2019          0
# ...

# %%
# Visualizar as 5 últimas linhas do Dataset.

df.tail()
# Out:
#           txNomeParlamentar          cpf  ideCadastro  nuCarteiraParlamentar  \
# 555495  Henrique do Paraíso  34709948895     217036.0                  588.0
# 555496  Henrique do Paraíso  34709948895     217036.0                  588.0
# 555497  Henrique do Paraíso  34709948895     217036.0                  588.0
# 555498  Henrique do Paraíso  34709948895     217036.0                  588.0
# 555499        DaLua do Rota  51172593272     217330.0                  590.0
#
#         nuLegislatura sgUF     sgPartido  codLegislatura  numSubCota  \
# 555495           2019   SP  REPUBLICANOS              56           5
# 555496           2019   SP  REPUBLICANOS              56           5
# 555497           2019   SP  REPUBLICANOS              56           5
# 555498           2019   SP  REPUBLICANOS              56          10
# 555499           2019   AP           PSC              56          10
#
#                                 txtDescricao  ...  numAno numParcela  \
# ...

# %%
print("O data frame total possui " + str(df.shape[0]) + " linhas e " + str(df.shape[1]) + " colunas!")
# Out:
# O data frame total possui 555500 linhas e 31 colunas!

# %% [markdown]
# ---

# %% [markdown]
# ## **5. Preparação e limpeza dos Dados:**

# %% [markdown]
# ### **5.1 Selecionando os dados:**

# %% [markdown]
# Primeiro começamos separando o DF filtrando o estado do RS do DF geral.

# %%
dfRS = df.query('sgUF == "RS"')
dfRS.head()
# Out:
#      txNomeParlamentar          cpf  ideCadastro  nuCarteiraParlamentar  \
# 6712  Henrique Fontana  33410518053      73482.0                  498.0
# 6713  Henrique Fontana  33410518053      73482.0                  498.0
# 6714  Henrique Fontana  33410518053      73482.0                  498.0
# 6715  Henrique Fontana  33410518053      73482.0                  498.0
# 6716  Henrique Fontana  33410518053      73482.0                  498.0
#
#       nuLegislatura sgUF sgPartido  codLegislatura  numSubCota  \
# 6712           2015   RS        PT              55           1
# 6713           2015   RS        PT              55           1
# 6714           2015   RS        PT              55           1
# 6715           2015   RS        PT              55           1
# 6716           2015   RS        PT              55           1
#
#                                            txtDescricao  ...  numAno  \
# 6712  MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE ...  ...    2019
# ...

# %% [markdown]
# Analisando agora a quantidade de linhas do dfRS temos que:

# %%
porct = (dfRS.shape[0]/df.shape[0])*100
print("O dataset original possui: " + str(df.shape[0]) + " linhas, enquanto a amostragem utilizada (RS) tem: " + str(dfRS.shape[0]) + " linhas, ou seja, " + str(round(porct,2)) + "% do total.")
# Out:
# O dataset original possui: 555500 linhas, enquanto a amostragem utilizada (RS) tem: 48467 linhas, ou seja, 8.72% do total.

# %% [markdown]
# Montando dois dataframes com valores liquidos positivos e negativos separados:

# %%
dados_positivos = dfRS[dfRS.vlrLiquido >= 0]
dados_negativos = dfRS[dfRS.vlrLiquido < 0]

# %% [markdown]
# ### **5.2 Consulta extra:**

# %% [markdown]
# Verificando as colunas:

# %%
dfRS.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 90340 entries, 6712 to 48466
# Data columns (total 34 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   txNomeParlamentar          48467 non-null  object
#  1   cpf                        48462 non-null  object
#  2   ideCadastro                48467 non-null  float64
#  3   nuCarteiraParlamentar      48467 non-null  float64
#  4   nuLegislatura              48467 non-null  float64
#  5   sgUF                       48467 non-null  object
#  6   sgPartido                  48467 non-null  object
#  7   codLegislatura             48467 non-null  float64
#  8   numSubCota                 48467 non-null  float64
#  9   txtDescricao               48467 non-null  object
#  10  numEspecificacaoSubCota    48467 non-null  float64
#  11  txtDescricaoEspecificacao  14380 non-null  object
#  12  txtFornecedor              48465 non-null  object
# ...

# %% [markdown]
# Quantidade de ocorrência dos partidos ao longo dos dataframes

# %%
dfRS['sgPartido'].value_counts()
# Out:
# PT              8664
# PSL             7486
# MDB             6210
# PP              5307
# PDT             5198
# PTB             4384
# PSB             2717
# PL              2344
# PSDB            1993
# REPUBLICANOS    1360
# PSD             1244
# PSOL             869
# NOVO             574
# PRB               39
# REDE              32
# PR                31
# DEM               10
# PODE               5
# Name: sgPartido, dtype: int64

# %% [markdown]
# ### **5.3 Convertendo os valores:**

# %% [markdown]
# Alterando a coluna 'dataEmissao' para datetime

# %%
dfRS.datEmissao.fillna(0,inplace=True)
dfRS.datEmissao = pd.to_datetime(dfRS.datEmissao,format = '%Y/%m/%d')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/arrays/datetimes.py in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object, allow_mixed)
#    2191         try:
# -> 2192             values, tz_parsed = conversion.datetime_to_datetime64(data.ravel("K"))
#    2193             # If tzaware, these values represent unix timestamps, so we
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/tslibs/conversion.pyx in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'int'>
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-39-cc1eb5c4c267> in <module>()
#       1 dfRS.datEmissao.fillna(0,inplace=True)
# ...

# %% [markdown]
# Cria coluna com o nome do dia da semana

# %%
diaSemana = dfRS.datEmissao
lista = []
for i in diaSemana:
   lista.append(calendar.day_name[i.weekday()])
DiaSemana = pd.Series(lista)
dfRS = pd.concat([dfRS,DiaSemana],axis=1)
dfRS.rename(columns={0:'DiaSemana'},inplace=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-40-187a6770bd9e> in <module>()
#       2 lista = []
#       3 for i in diaSemana:
# ----> 4    lista.append(calendar.day_name[i.weekday()])
#       5 DiaSemana = pd.Series(lista)
#       6 dfRS = pd.concat([dfRS,DiaSemana],axis=1)
#
# AttributeError: 'int' object has no attribute 'weekday'

# %%
# df['cotaUF'] = df.sgUF.astype('str')
# dic_uf={}
# for i,j in df_cotas.iterrows():
#     dic_uf[j.Estado]=j[1]

# def insere_cotas(x,y):
#     for i,j in y.items():
#         if x==i:
#             x=j
#     return x

# df['cotaUF'] = df.cotaUF.apply(lambda x: insere_cotas(x,dic_uf))

# %%
# criamos uma função pra inserir o mes por extenso e assim poder criar a coluna 'Datacompleta' e plotar os graficos com um entendimento melhor
def mes_extenso(x,dic):
    for i,j in dic.items():
        if x == i:
            x=j
    return x

# %%
# Lista com os meses por extenso 
meses = {1:'Janeiro',2:'Fevereiro',3:'Marco',4:'Abril',5:'Maio',6:'Junho',7:'Julho',8:'Agosto',9:'Setembro',10:'Outubro',11:'Novembro',12:'Dezembro'}

# Aqui usamos a função que criamos para colocar os meses por extenso e criamos uma coluna 'Datacompleta' para colocar o mes e o ano em uma unica coluna
dfRS.sort_values(['numAno','numMes'],inplace=True)
dfRS['Mes']=dfRS.numMes.apply(lambda x :mes_extenso(x,meses))
dfRS['Datacompleta'] = dfRS['numMes']
for i in dfRS.iterrows():
    if i[0]<=len(dfRS)-1:
        dfRS['Datacompleta'][i[0]]=f'{dfRS.Mes[i[0]]} de {dfRS.numAno[i[0]]}'

# %% [markdown]
# ### **5.4 Estatísticas Descritivas:**

# %%
pd.options.display.float_format = '{:,.2f}'.format
#Caso as variáveis fiquem em notação científica, é só rodar essa janela

# %%
dfRS.describe().T
# Out:
#                             count         mean          std       min  \
# ideCadastro             48,467.00   153,803.75    48,923.47 73,482.00
# nuCarteiraParlamentar   48,467.00       504.38        12.29    486.00
# nuLegislatura           48,467.00     2,018.92         0.56  2,015.00
# codLegislatura          48,467.00        55.98         0.14     55.00
# numSubCota              48,467.00       182.44       358.33      1.00
# numEspecificacaoSubCota 48,467.00         0.30         0.46      0.00
# indTipoDocumento        48,467.00         1.69         1.81      0.00
# vlrDocumento            48,467.00       568.06     1,473.80 -3,232.62
# vlrGlosa                48,467.00         2.77        35.12      0.00
# vlrLiquido              48,467.00       517.38     1,484.34 -4,481.70
# numMes                  48,467.00         6.16         3.33      1.00
# numAno                  48,467.00     2,019.67         0.77  2,019.00
# ...

# %% [markdown]
# ---

# %% [markdown]
# ## **6. Análise Exploratória:**

# %% [markdown]
# Temos abaixo a resolução das questões solicitadas pelo projeto e as que foram sugeridas pela equipe:

# %% [markdown]
# ##**Questões propostas pela equipe:**

# %% [markdown]
# ### **1.0. Quais os maiores e menores valores de gastos de cada parlamentar e seu partido?**

# %%
dadosqs1a = dfRS.groupby('txNomeParlamentar')[['vlrLiquido']].sum().sort_values('vlrLiquido', ascending = False) #adicionei mes e ano no groupby só para ordenar de forma correta
dadosqs1a.head(5)
# Out:
#                    vlrLiquido
# txNomeParlamentar
# Nereu Crispim      1233088.59
# Afonso Motta       1177066.98
# Pompeo de Mattos   1166408.51
# Paulo Pimenta      1157436.08
# Giovani Cherini    1092324.64

# %%
dadosqs1b = dfRS.groupby(['sgPartido','txNomeParlamentar'])[['vlrLiquido']].sum().sort_values('vlrLiquido', ascending = True) #adicionei mes e ano no groupby só para ordenar de forma correta
dadosqs1b.head(5)
# Out:
#                                       vlrLiquido
# sgPartido txNomeParlamentar
# PP        RENATO MOLLING                  472.32
# DEM       Onyx Lorenzoni                  748.60
# PDT       WASHINGTON CORAÇÃO VALENTE     6160.47
# PTB       SÉRGIO MORAES                  8374.77
# PSDB      YEDA CRUSIUS                  12988.42

# %% [markdown]
# ### **2.0. Quais os partidos do RS que mais consumiram recursos?**

# %%
questao3_1 = dfRS.groupby('sgPartido')[['vlrLiquido']].sum().sort_values('vlrLiquido', ascending=False).head(10)
questao3_1.head(5)
# Out:
#            vlrLiquido
# sgPartido
# PT         4584718.12
# MDB        3580268.83
# PDT        3317536.88
# PSL        3174757.30
# PP         2845271.23

# %% [markdown]
# ### **3.0. Existe correlação entre o número de representantes e gastos?**

# %%
parlamentaresTotal = dfRS[['sgPartido','txNomeParlamentar']].drop_duplicates().groupby('sgPartido').count().sort_values('txNomeParlamentar',ascending=False)
parlamentaresTotal.head(5)

# %%
total_por_partido = pd.concat([parlamentaresTotal,questao3_1],axis=1)
total_por_partido.head(5)

# %%
result = total_por_partido[['txNomeParlamentar','vlrLiquido']].corr().round(2)
result

# %% [markdown]
# ### **4.0. Qual é média de Gastos por parlamentar do RS comparado com o Brasil?**

# %%
mediaBR = round(df['vlrDocumento'].mean(),2)
mediaBR

# %%
questao5 = dfRS.groupby(['sgPartido','txNomeParlamentar']).mean()[['vlrLiquido']].sort_values('vlrLiquido',ascending=False)
questao5['mediaBR'] = mediaBR
questao5['Porcentagem (%)'] = (questao5['vlrLiquido']/questao5['mediaBR'])*100
questao5.tail(5)

# %% [markdown]
# ### **5.0. Qual é a média de Gastos por partido do RS comparado com o Brasil?**

# %%
mediaBR = round(df['vlrDocumento'].mean(),2)
mediaBR

# %%
questao5 = dfRS.groupby(['sgPartido']).mean()[['vlrLiquido']].sort_values('vlrLiquido',ascending=False)
questao5['mediaBR'] = mediaBR
questao5['Porcentagem (%)'] = (questao5['vlrLiquido']/questao5['mediaBR'])*100
questao5.head(5)

# %% [markdown]
# ### **6.0. Qual parlamentar do RS mais viajou?**

# %% [markdown]
# ### **7.0. Qual teve o maior e menor gasto?**

# %%
questao8 = dfRS.groupby(['sgPartido','txNomeParlamentar'])[['vlrLiquido']].sum().sort_values('vlrLiquido', ascending=False)
questao8.head(5)

# %%
questao8 = dfRS.groupby(['sgPartido','txNomeParlamentar'])[['vlrLiquido']].sum().sort_values('vlrLiquido', ascending=True)
questao8.head(5)

# %% [markdown]
# ### **8.0. Houve algo específico durante o período de tempo analisado que se sobressaiu? Se sim pq?**

# %% [markdown]
# ### **9.0. Verificar a quantidade de mulheres que são parlamentares no Brasil e no RS (Comparar os dois). Entender se existe diversidade.**

# %% [markdown]
# ### **10.0. Verificar se tem relação entre número de ocorrências do parlamentar no dataset com o número de gastos dele.**

# %% [markdown]
# Questão analisando correlação entre ocorrência de nome do parlamentar no csv com os gastos do mesmo

# %%
mandioca = total_par.join(cebola)

# %%
resultbatata = mandioca[['vlrLiquido','txNomeParlamentar']].corr().round(2)
resultbatata
# Out:
#                    vlrLiquido  txNomeParlamentar
# vlrLiquido               1.00               0.88
# txNomeParlamentar        0.88               1.00

# %%
aipo = mandioca.sort_values('vlrLiquido', ascending = False)

# %%
cebola = dfRS['txNomeParlamentar'].value_counts()
alho = pd.DataFrame(cebola)

# %%
total_par = pd.pivot_table(dfRS, values='vlrLiquido', index=['txNomeParlamentar'], aggfunc=np.sum)
beterraba = total_par.sort_values(by='vlrLiquido', ascending=False)

# %% [markdown]
# ---

# %% [markdown]
# ##**Conclusão**

# %% [markdown]
# Podemos concluir que a partir das análises realizadas. Temos uma fagulha de esperança na questão da diversidade, pois, mesmo tendo casos como o Sergipe que não possui mulheres parlamentares, ainda assim temos casos como Amapá e o Acre em que as quantidades de homens e mulheres estão mais niveladas. Já no caso do Rio Grande do Sul, podemos ver que ainda há um caminho a ser percorrido nesse quesito, pois, a quantidade de mulheres equivale a aproximadamente 10% do todo. Vale ressaltar também que os gastos possuem comportamento parecido com o que vimos na operação anterior ([Serenata de Amor](https://serenata.ai/)), ou seja, são gastos excessivos com itens parecidos com o que já foi visto. Foi interessante ver que o mesmo partido que gastou mais no Brasil também teve destaque no Estado estudado, além disso foi interessante ver que o parlamentar que mais gastou, gastou pouco menos do que a parlamentar que gastou mais no Brasil. Já em relação a plataforma utilizada para realizar as visualizações, no caso, o Power BI; podemos dizer que é um software intuitivo e com muitas possibilidades de resultados, o que ajuda a montar uma apresentação e auxilia muito bem na questão de storytelling.

# %% [markdown]
# ##**Referências**
